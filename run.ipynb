# %%
from perform_experiment import perform_experiment

# %%
perform_experiment(
    1, 20034, 10000,
    
    10, 3, 252,
    "./data/download/train.bin",
    "./data/download/test.bin",
    "./data/tmp/paulis.bin",
    
    "./data/out/K_train_train_0", "./data/out/K_test_train_01"
)
# Out:
# Computing the NTK matrices for various sampled thetas:
# 100%|██████████| 1/1 [00:13<00:00, 13.93s/it]
# Saving the K_train_train to ./data/out/K_train_train_0...
# Done. Elapsed = 1.4629488710015721s.
# Saving the K_test_train to ./data/out/K_test_train_01...
# Done. Elapsed = 0.7340394980019482s.
