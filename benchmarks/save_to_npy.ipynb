# %%
import numpy as np
import gc

# %%
size = 40000
mat = np.random.random((size, size))
mat

del mat
gc.collect()
# Out:
# 31

# %%
path = "test_out/test.npy"
np.save(path, mat)

# %%
for i in range(10):
    j = 1
    k = i

# %%
del i, j

# %%
import gc
gc.collect()
# Out:
# 96
